# %%
# !pip install nltk --q
# !pip install kaggle --q

# %%
import os
import sys
import json
from zipfile import ZipFile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import nltk
# from wordcloud import WordCloud, STOPWORDS

from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import wordnet, stopwords

import re, string, unicodedata
from sklearn.metrics import classification_report, f1_score, confusion_matrix, accuracy_score, recall_score, precision_score, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

from sklearn.pipeline import make_pipeline, Pipeline

from string import punctuation
from prettytable import PrettyTable #used to create and display ASCII tables in a readable format

import warnings
warnings.filterwarnings('ignore')

import scipy as sp

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/pragya/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/pragya/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/pragya/nltk_data...
# True

# %%
kaggle_credential = json.load(open('kaggle.json'))

os.environ['KAGGLE_USERNAME'] = kaggle_credential['username']
os.environ['KAGGLE_KEY'] = kaggle_credential['key']

# %%
# !kaggle datasets download -d crisbam/imdb-dataset-of-65k-movie-reviews-and-translation
# Out:
# Downloading imdb-dataset-of-65k-movie-reviews-and-translation.zip to /Users/pragya/Desktop/LEARN/NLP Projects/SentimentAnalysis
# 100%|████████████████████████████████████████| 147M/147M [00:26<00:00, 6.14MB/s]
# 100%|████████████████████████████████████████| 147M/147M [00:26<00:00, 5.88MB/s]

# %%
# !ls
# Out:
# SA_ModelSelection.ipynb
# imdb-dataset-of-65k-movie-reviews-and-translation.zip
# kaggle.json

# %%
with ZipFile('imdb-dataset-of-65k-movie-reviews-and-translation.zip', 'r') as zipref:
  zipref.extractall()

# %%
df = pd.read_csv('IMDB-Dataset.csv')

# %% [markdown]
# ## Data preprocessing

# %%
stop_words = stopwords.words('english')
stop_words.remove("not")

new_stopwords = ["might", "could", "one", "film", "movie", "would", "shall"]
stop_words.extend(new_stopwords)

stop_words = set(stop_words)

# %%
contraction_mapping = {
    "won't": "would not",
    "can't": "can not",
    "don't": "do not",
    "shouldn't": "should not",
    "needn't": "need not",
    "hasn't": "has not",
    "haven't": "have not",
    "weren't": "were not",
    "mightn't": "might not",
    "didn't": "did not"
}

def preprocessing_text(text):

  for contraction, expanded_form in contraction_mapping.items():
    text = re.sub(r"\b" + re.escape(contraction) + r"\b", expanded_form, text)

    text = text.lower()
    text = re.sub('<.*?>', ' ', text)
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    text = re.sub('https\S\s',  ' ', text)

    text = nltk.word_tokenize(text)

    text = [word for word in text if word not in stop_words]

    lmtr = WordNetLemmatizer()

    text = [lmtr.lemmatize(word) for word in text]

    return " ".join(text)

# %%
df['Clean_Review'] = df['Reviews'].apply(preprocessing_text)

# %% [markdown]
# ## Feature Engineering

# %%
df['Label'] = df['Ratings'].apply(lambda x: '1' if x >=7 else ('0' if x <=4 else '2'))
df = df[df['Label'] < '2']

# %%
X_train, X_test, y_train, y_test = train_test_split(df['Clean_Review'], df['Label'], test_size = 0.2, random_state = 42, stratify = df['Label'], shuffle = True)

# %%
tfidfvect = TfidfVectorizer(analyzer = "word", ngram_range=(1,3), min_df = 10, max_features = 10000)

X_train_tfidf = tfidfvect.fit_transform(X_train).toarray()
X_test_tfidf  = tfidfvect.fit_transform(X_test).toarray()

# %% [markdown]
# #Model selection
#
# The `average` parameter in Scikit-learn's precision_score function specifies how to average the data to compute the precision score in multiclass or multilabel classification. Understanding these averaging methods is crucial as they influence the calculation of the scores.
#
# 1. **Micro Averaging (`average='micro'`)**: Aggregates the contributions of all classes by counting the total true positives, false negatives, and false positives, and then calculates the precision from these aggregated counts. Useful for evaluating overall model performance, treating each individual prediction equally.
#
# 2. **Macro Averaging (`average='macro'`)**: Calculates the precision for each class independently and then takes the unweighted average of these precisions. Useful when you want to give equal importance to each class, regardless of their frequency.
#
# 3. **Weighted Averaging (`average='weighted'`)**: Calculates the precision for each class independently and then takes the average weighted by the number of true instances for each class. Useful for accounting for class imbalance while still providing a single average precision score.
#
# 4. **Samples Averaging (`average='samples'`)**: Calculates the precision for each instance and then averages over all instances. Useful for multilabel classification where performance needs to be evaluated on a per-sample basis.
#
# ### Logistic Regression

# %%
model_1 = Pipeline(
    steps=[
        ("classifier", LogisticRegression())
    ]
)

# %%
model_1.fit(X_train_tfidf, y_train)
# Out:
# Pipeline(steps=[('classifier', LogisticRegression())])

# %%
# ovo Stands for "One-Versus-One". It means the model will build a binary classifier for every pair of classes.
# For N classes, the ovo will give N(N-1)/2 classifiers and the class with maximum score would be chosen.

f1_score_1 = f1_score(y_test, model_1.predict(X_test_tfidf), average = 'weighted')

print("Training dataset:")
print("Precision Score", precision_score(y_train, model_1.predict(X_train_tfidf), average = 'micro'))
print("f1 Score", f1_score(y_train, model_1.predict(X_train_tfidf), average = 'weighted'))
print(" ")

print("Test dataset:")
print("Precision Score", precision_score(y_test, model_1.predict(X_test_tfidf), average = 'micro'))
print("f1 Score", f1_score(y_test, model_1.predict(X_test_tfidf), average = 'weighted'))
print(" ")
# Out:
# Training dataset:
# Precision Score 0.9132291666666666
# f1 Score 0.9132286857713058
#
# Test dataset:
# Precision Score 0.6057083333333333
# f1 Score 0.6048585260267842

# %% [markdown]
# ### Decision Tree Classifier

# %%
model_2 = Pipeline(
    steps=[
        ('classifier', DecisionTreeClassifier(criterion = 'gini', max_depth = 11, min_samples_split = 2, min_samples_leaf = 1))
    ]
)

# %%
model_2.fit(X_train_tfidf, y_train)
# Out:
# Pipeline(steps=[('classifier', DecisionTreeClassifier(max_depth=11))])

# %%
f1_score_2 = f1_score(y_test, model_2.predict(X_test_tfidf), average = 'weighted')

print("Training dataset:")
print("Precision Score", precision_score(y_train, model_2.predict(X_train_tfidf), average = 'micro'))
print("f1 Score", f1_score(y_train, model_2.predict(X_train_tfidf), average = 'weighted'))
print(" ")

print("Test dataset:")
print("Precision Score", precision_score(y_test, model_2.predict(X_test_tfidf), average = 'micro'))
print("f1 Score", f1_score(y_test, model_2.predict(X_test_tfidf), average = 'weighted'))
print(" ")
# Out:
# Training dataset:
# Precision Score 0.74753125
# f1 Score 0.7440291363849421
#
# Test dataset:
# Precision Score 0.521875
# f1 Score 0.4045031690907737

# %% [markdown]
# ### Random Forest Classifier

# %%
model_3 = Pipeline(
    steps=[
        ('classifier', RandomForestClassifier())
    ]
)

model_3.fit(X_train_tfidf, y_train)
# Out:
# Pipeline(steps=[('classifier', RandomForestClassifier())])

# %%
f1_score_3 = f1_score(y_test, model_3.predict(X_test_tfidf), average = 'weighted')

print("Training dataset:")
print("Precision Score", precision_score(y_train, model_3.predict(X_train_tfidf), average = 'micro'))
print("f1 Score", f1_score(y_train, model_3.predict(X_train_tfidf), average = 'weighted'))
print(" ")

print("Test dataset:")
print("Precision Score", precision_score(y_test, model_3.redict(X_test_tfidf), average = 'micro'))
print("f1 Score", f1_score(y_test, model_3.predict(X_test_tfidf), average = 'weighted'))
print(" ")
# Out:
# Training dataset:
# Precision Score 0.9999270833333334
# f1 Score 0.9999270833331355
#
# Test dataset:
# Precision Score 0.5899166666666666
# f1 Score 0.5754654028458915

# %% [markdown]
# ### Adaboost classifier

# %%
model_4 = Pipeline(
    steps=[
        ('classifier', AdaBoostClassifier(
            estimator=DecisionTreeClassifier(max_depth=4),  # Specify base estimator
            n_estimators=100,
            learning_rate=0.8
        ))
    ]
)


model_4.fit(X_train_tfidf, y_train)
# Out:
# Pipeline(steps=[('classifier',
#                  AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=4),
#                                     learning_rate=0.8, n_estimators=100))])

# %%
f1_score_4 = f1_score(y_test, model_4.predict(X_test_tfidf), average = 'weighted')

print("Training dataset:")
print("Precision Score", precision_score(y_train, model_4.predict(X_train_tfidf), average = 'micro'))
print("f1 Score", f1_score(y_train, model_4.predict(X_train_tfidf), average = 'weighted'))
print(" ")

print("Test dataset:")
print("Precision Score", precision_score(y_test, model_4.predict(X_test_tfidf), average = 'micro'))
print("f1 Score", f1_score(y_test, model_4.predict(X_test_tfidf), average = 'weighted'))
print(" ")
# Out:
# Training dataset:
# Precision Score 0.896875
# f1 Score 0.8968744183072659
#
# Test dataset:
# Precision Score 0.57225
# f1 Score 0.5649923197796571

# %% [markdown]
# ### Hyperparameter tuning with grid search

# %%
from sklearn import ensemble, metrics, model_selection

# %%
def hyperparamtune(classifier, param_grid, metric, verbose_value, cv):
    model = model_selection.GridSearchCV(
        estimator = classifier, 
        param_grid = param_grid,
        scoring = metric, 
        verbose = verbose_value,
        cv = cv
    )

    model.fit(X_train_tfidf, y_train)
    print(f'Best Score: {model.best_score_}')
    print('Best hyperparameter set:')

    best_parameters = model.best_estimator_.get_params()
    for param_name in sorted(param_grid.keys()):
        print(f"\t{param_name}: {best_parameters[param_name]}")
    return model, best_parameters

# %% [markdown]
# ### Hyperparameter tuning of logistic regression

# %%
param_gd={"penalty":["l2","l1"],
         "C":[0.01,0.1,1.0,10],
         "tol":[0.0001,0.001,0.01],
         "max_iter":[100,200]}
model_5, best_param = hyperparamtune(LogisticRegression(), param_gd, "accuracy", 10, 5)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5; 1/48] START C=0.01, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 1/5; 1/48] END C=0.01, max_iter=100, penalty=l2, tol=0.0001;, score=0.858 total time=  30.5s
# [CV 2/5; 1/48] START C=0.01, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 2/5; 1/48] END C=0.01, max_iter=100, penalty=l2, tol=0.0001;, score=0.858 total time=  29.9s
# [CV 3/5; 1/48] START C=0.01, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 3/5; 1/48] END C=0.01, max_iter=100, penalty=l2, tol=0.0001;, score=0.860 total time=  25.3s
# [CV 4/5; 1/48] START C=0.01, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 4/5; 1/48] END C=0.01, max_iter=100, penalty=l2, tol=0.0001;, score=0.861 total time=  25.0s
# [CV 5/5; 1/48] START C=0.01, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 5/5; 1/48] END C=0.01, max_iter=100, penalty=l2, tol=0.0001;, score=0.859 total time=  24.4s
# [CV 1/5; 2/48] START C=0.01, max_iter=100, penalty=l2, tol=0.001................
# [CV 1/5; 2/48] END C=0.01, max_iter=100, penalty=l2, tol=0.001;, score=0.844 total time=  18.3s
# [CV 2/5; 2/48] START C=0.01, max_iter=100, penalty=l2, tol=0.001................
# [CV 2/5; 2/48] END C=0.01, max_iter=100, penalty=l2, tol=0.001;, score=0.846 total time=  17.0s
# [CV 3/5; 2/48] START C=0.01, max_iter=100, penalty=l2, tol=0.001................
# [CV 3/5; 2/48] END C=0.01, max_iter=100, penalty=l2, tol=0.001;, score=0.850 total time=  18.3s
# [CV 4/5; 2/48] START C=0.01, max_iter=100, penalty=l2, tol=0.001................
# [CV 4/5; 2/48] END C=0.01, max_iter=100, penalty=l2, tol=0.001;, score=0.851 total time=  19.0s
# [CV 5/5; 2/48] START C=0.01, max_iter=100, penalty=l2, tol=0.001................
# [CV 5/5; 2/48] END C=0.01, max_iter=100, penalty=l2, tol=0.001;, score=0.846 total time=  17.8s
# [CV 1/5; 3/48] START C=0.01, max_iter=100, penalty=l2, tol=0.01.................
# [CV 1/5; 3/48] END C=0.01, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=   9.0s
# [CV 2/5; 3/48] START C=0.01, max_iter=100, penalty=l2, tol=0.01.................
# [CV 2/5; 3/48] END C=0.01, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=   9.0s
# [CV 3/5; 3/48] START C=0.01, max_iter=100, penalty=l2, tol=0.01.................
# [CV 3/5; 3/48] END C=0.01, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=   9.6s
# [CV 4/5; 3/48] START C=0.01, max_iter=100, penalty=l2, tol=0.01.................
# [CV 4/5; 3/48] END C=0.01, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=   9.7s
# [CV 5/5; 3/48] START C=0.01, max_iter=100, penalty=l2, tol=0.01.................
# [CV 5/5; 3/48] END C=0.01, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=   9.2s
# [CV 1/5; 4/48] START C=0.01, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 1/5; 4/48] END C=0.01, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   4.1s
# [CV 2/5; 4/48] START C=0.01, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 2/5; 4/48] END C=0.01, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   3.7s
# [CV 3/5; 4/48] START C=0.01, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 3/5; 4/48] END C=0.01, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   3.7s
# [CV 4/5; 4/48] START C=0.01, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 4/5; 4/48] END C=0.01, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   4.3s
# [CV 5/5; 4/48] START C=0.01, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 5/5; 4/48] END C=0.01, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   4.3s
# [CV 1/5; 5/48] START C=0.01, max_iter=100, penalty=l1, tol=0.001................
# [CV 1/5; 5/48] END C=0.01, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   4.3s
# [CV 2/5; 5/48] START C=0.01, max_iter=100, penalty=l1, tol=0.001................
# [CV 2/5; 5/48] END C=0.01, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   3.7s
# [CV 3/5; 5/48] START C=0.01, max_iter=100, penalty=l1, tol=0.001................
# [CV 3/5; 5/48] END C=0.01, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   3.6s
# [CV 4/5; 5/48] START C=0.01, max_iter=100, penalty=l1, tol=0.001................
# [CV 4/5; 5/48] END C=0.01, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   4.2s
# [CV 5/5; 5/48] START C=0.01, max_iter=100, penalty=l1, tol=0.001................
# [CV 5/5; 5/48] END C=0.01, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   4.3s
# [CV 1/5; 6/48] START C=0.01, max_iter=100, penalty=l1, tol=0.01.................
# [CV 1/5; 6/48] END C=0.01, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   4.6s
# [CV 2/5; 6/48] START C=0.01, max_iter=100, penalty=l1, tol=0.01.................
# [CV 2/5; 6/48] END C=0.01, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   3.8s
# [CV 3/5; 6/48] START C=0.01, max_iter=100, penalty=l1, tol=0.01.................
# [CV 3/5; 6/48] END C=0.01, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   3.6s
# [CV 4/5; 6/48] START C=0.01, max_iter=100, penalty=l1, tol=0.01.................
# [CV 4/5; 6/48] END C=0.01, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   4.2s
# [CV 5/5; 6/48] START C=0.01, max_iter=100, penalty=l1, tol=0.01.................
# [CV 5/5; 6/48] END C=0.01, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   4.3s
# [CV 1/5; 7/48] START C=0.01, max_iter=200, penalty=l2, tol=0.0001...............
# [CV 1/5; 7/48] END C=0.01, max_iter=200, penalty=l2, tol=0.0001;, score=0.858 total time=  25.0s
# [CV 2/5; 7/48] START C=0.01, max_iter=200, penalty=l2, tol=0.0001...............
# [CV 2/5; 7/48] END C=0.01, max_iter=200, penalty=l2, tol=0.0001;, score=0.858 total time=  23.9s
# [CV 3/5; 7/48] START C=0.01, max_iter=200, penalty=l2, tol=0.0001...............
# [CV 3/5; 7/48] END C=0.01, max_iter=200, penalty=l2, tol=0.0001;, score=0.860 total time=  24.5s
# [CV 4/5; 7/48] START C=0.01, max_iter=200, penalty=l2, tol=0.0001...............
# [CV 4/5; 7/48] END C=0.01, max_iter=200, penalty=l2, tol=0.0001;, score=0.861 total time=  25.3s
# [CV 5/5; 7/48] START C=0.01, max_iter=200, penalty=l2, tol=0.0001...............
# [CV 5/5; 7/48] END C=0.01, max_iter=200, penalty=l2, tol=0.0001;, score=0.859 total time=  27.1s
# [CV 1/5; 8/48] START C=0.01, max_iter=200, penalty=l2, tol=0.001................
# [CV 1/5; 8/48] END C=0.01, max_iter=200, penalty=l2, tol=0.001;, score=0.844 total time=  18.8s
# [CV 2/5; 8/48] START C=0.01, max_iter=200, penalty=l2, tol=0.001................
# [CV 2/5; 8/48] END C=0.01, max_iter=200, penalty=l2, tol=0.001;, score=0.846 total time=  18.7s
# [CV 3/5; 8/48] START C=0.01, max_iter=200, penalty=l2, tol=0.001................
# [CV 3/5; 8/48] END C=0.01, max_iter=200, penalty=l2, tol=0.001;, score=0.850 total time=  18.9s
# [CV 4/5; 8/48] START C=0.01, max_iter=200, penalty=l2, tol=0.001................
# [CV 4/5; 8/48] END C=0.01, max_iter=200, penalty=l2, tol=0.001;, score=0.851 total time=  18.2s
# [CV 5/5; 8/48] START C=0.01, max_iter=200, penalty=l2, tol=0.001................
# [CV 5/5; 8/48] END C=0.01, max_iter=200, penalty=l2, tol=0.001;, score=0.846 total time=  18.7s
# [CV 1/5; 9/48] START C=0.01, max_iter=200, penalty=l2, tol=0.01.................
# [CV 1/5; 9/48] END C=0.01, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=   9.6s
# [CV 2/5; 9/48] START C=0.01, max_iter=200, penalty=l2, tol=0.01.................
# [CV 2/5; 9/48] END C=0.01, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=  10.1s
# [CV 3/5; 9/48] START C=0.01, max_iter=200, penalty=l2, tol=0.01.................
# [CV 3/5; 9/48] END C=0.01, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=   9.5s
# [CV 4/5; 9/48] START C=0.01, max_iter=200, penalty=l2, tol=0.01.................
# [CV 4/5; 9/48] END C=0.01, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=   9.1s
# [CV 5/5; 9/48] START C=0.01, max_iter=200, penalty=l2, tol=0.01.................
# [CV 5/5; 9/48] END C=0.01, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=   9.6s
# [CV 1/5; 10/48] START C=0.01, max_iter=200, penalty=l1, tol=0.0001..............
# [CV 1/5; 10/48] END C=0.01, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   4.1s
# [CV 2/5; 10/48] START C=0.01, max_iter=200, penalty=l1, tol=0.0001..............
# [CV 2/5; 10/48] END C=0.01, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   4.1s
# [CV 3/5; 10/48] START C=0.01, max_iter=200, penalty=l1, tol=0.0001..............
# [CV 3/5; 10/48] END C=0.01, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   3.8s
# [CV 4/5; 10/48] START C=0.01, max_iter=200, penalty=l1, tol=0.0001..............
# [CV 4/5; 10/48] END C=0.01, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   4.3s
# [CV 5/5; 10/48] START C=0.01, max_iter=200, penalty=l1, tol=0.0001..............
# [CV 5/5; 10/48] END C=0.01, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   4.2s
# [CV 1/5; 11/48] START C=0.01, max_iter=200, penalty=l1, tol=0.001...............
# [CV 1/5; 11/48] END C=0.01, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   4.3s
# [CV 2/5; 11/48] START C=0.01, max_iter=200, penalty=l1, tol=0.001...............
# [CV 2/5; 11/48] END C=0.01, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   3.7s
# [CV 3/5; 11/48] START C=0.01, max_iter=200, penalty=l1, tol=0.001...............
# [CV 3/5; 11/48] END C=0.01, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   3.6s
# [CV 4/5; 11/48] START C=0.01, max_iter=200, penalty=l1, tol=0.001...............
# [CV 4/5; 11/48] END C=0.01, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   4.2s
# [CV 5/5; 11/48] START C=0.01, max_iter=200, penalty=l1, tol=0.001...............
# [CV 5/5; 11/48] END C=0.01, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   4.1s
# [CV 1/5; 12/48] START C=0.01, max_iter=200, penalty=l1, tol=0.01................
# [CV 1/5; 12/48] END C=0.01, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   4.3s
# [CV 2/5; 12/48] START C=0.01, max_iter=200, penalty=l1, tol=0.01................
# [CV 2/5; 12/48] END C=0.01, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   3.7s
# [CV 3/5; 12/48] START C=0.01, max_iter=200, penalty=l1, tol=0.01................
# [CV 3/5; 12/48] END C=0.01, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   3.6s
# [CV 4/5; 12/48] START C=0.01, max_iter=200, penalty=l1, tol=0.01................
# [CV 4/5; 12/48] END C=0.01, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   4.1s
# [CV 5/5; 12/48] START C=0.01, max_iter=200, penalty=l1, tol=0.01................
# [CV 5/5; 12/48] END C=0.01, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   4.3s
# [CV 1/5; 13/48] START C=0.1, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 1/5; 13/48] END C=0.1, max_iter=100, penalty=l2, tol=0.0001;, score=0.882 total time=  48.3s
# [CV 2/5; 13/48] START C=0.1, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 2/5; 13/48] END C=0.1, max_iter=100, penalty=l2, tol=0.0001;, score=0.880 total time=  48.0s
# [CV 3/5; 13/48] START C=0.1, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 3/5; 13/48] END C=0.1, max_iter=100, penalty=l2, tol=0.0001;, score=0.882 total time=  48.9s
# [CV 4/5; 13/48] START C=0.1, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 4/5; 13/48] END C=0.1, max_iter=100, penalty=l2, tol=0.0001;, score=0.882 total time=  49.7s
# [CV 5/5; 13/48] START C=0.1, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 5/5; 13/48] END C=0.1, max_iter=100, penalty=l2, tol=0.0001;, score=0.881 total time=  32.6s
# [CV 1/5; 14/48] START C=0.1, max_iter=100, penalty=l2, tol=0.001................
# [CV 1/5; 14/48] END C=0.1, max_iter=100, penalty=l2, tol=0.001;, score=0.846 total time=  20.6s
# [CV 2/5; 14/48] START C=0.1, max_iter=100, penalty=l2, tol=0.001................
# [CV 2/5; 14/48] END C=0.1, max_iter=100, penalty=l2, tol=0.001;, score=0.847 total time=  24.1s
# [CV 3/5; 14/48] START C=0.1, max_iter=100, penalty=l2, tol=0.001................
# [CV 3/5; 14/48] END C=0.1, max_iter=100, penalty=l2, tol=0.001;, score=0.850 total time=  22.9s
# [CV 4/5; 14/48] START C=0.1, max_iter=100, penalty=l2, tol=0.001................
# [CV 4/5; 14/48] END C=0.1, max_iter=100, penalty=l2, tol=0.001;, score=0.852 total time=  22.9s
# [CV 5/5; 14/48] START C=0.1, max_iter=100, penalty=l2, tol=0.001................
# [CV 5/5; 14/48] END C=0.1, max_iter=100, penalty=l2, tol=0.001;, score=0.846 total time=  20.3s
# [CV 1/5; 15/48] START C=0.1, max_iter=100, penalty=l2, tol=0.01.................
# [CV 1/5; 15/48] END C=0.1, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=   9.1s
# [CV 2/5; 15/48] START C=0.1, max_iter=100, penalty=l2, tol=0.01.................
# [CV 2/5; 15/48] END C=0.1, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=  10.6s
# [CV 3/5; 15/48] START C=0.1, max_iter=100, penalty=l2, tol=0.01.................
# [CV 3/5; 15/48] END C=0.1, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=   9.2s
# [CV 4/5; 15/48] START C=0.1, max_iter=100, penalty=l2, tol=0.01.................
# [CV 4/5; 15/48] END C=0.1, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=   9.4s
# [CV 5/5; 15/48] START C=0.1, max_iter=100, penalty=l2, tol=0.01.................
# [CV 5/5; 15/48] END C=0.1, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=   9.4s
# [CV 1/5; 16/48] START C=0.1, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 1/5; 16/48] END C=0.1, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   4.6s
# [CV 2/5; 16/48] START C=0.1, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 2/5; 16/48] END C=0.1, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   3.9s
# [CV 3/5; 16/48] START C=0.1, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 3/5; 16/48] END C=0.1, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   4.1s
# [CV 4/5; 16/48] START C=0.1, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 4/5; 16/48] END C=0.1, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   4.3s
# [CV 5/5; 16/48] START C=0.1, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 5/5; 16/48] END C=0.1, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   4.2s
# [CV 1/5; 17/48] START C=0.1, max_iter=100, penalty=l1, tol=0.001................
# [CV 1/5; 17/48] END C=0.1, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   4.7s
# [CV 2/5; 17/48] START C=0.1, max_iter=100, penalty=l1, tol=0.001................
# [CV 2/5; 17/48] END C=0.1, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   4.4s
# [CV 3/5; 17/48] START C=0.1, max_iter=100, penalty=l1, tol=0.001................
# [CV 3/5; 17/48] END C=0.1, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   4.0s
# [CV 4/5; 17/48] START C=0.1, max_iter=100, penalty=l1, tol=0.001................
# [CV 4/5; 17/48] END C=0.1, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   5.0s
# [CV 5/5; 17/48] START C=0.1, max_iter=100, penalty=l1, tol=0.001................
# [CV 5/5; 17/48] END C=0.1, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   4.8s
# [CV 1/5; 18/48] START C=0.1, max_iter=100, penalty=l1, tol=0.01.................
# [CV 1/5; 18/48] END C=0.1, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   4.7s
# [CV 2/5; 18/48] START C=0.1, max_iter=100, penalty=l1, tol=0.01.................
# [CV 2/5; 18/48] END C=0.1, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   4.3s
# [CV 3/5; 18/48] START C=0.1, max_iter=100, penalty=l1, tol=0.01.................
# [CV 3/5; 18/48] END C=0.1, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   3.8s
# [CV 4/5; 18/48] START C=0.1, max_iter=100, penalty=l1, tol=0.01.................
# [CV 4/5; 18/48] END C=0.1, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   4.5s
# [CV 5/5; 18/48] START C=0.1, max_iter=100, penalty=l1, tol=0.01.................
# [CV 5/5; 18/48] END C=0.1, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   4.3s
# [CV 1/5; 19/48] START C=0.1, max_iter=200, penalty=l2, tol=0.0001...............
# [CV 1/5; 19/48] END C=0.1, max_iter=200, penalty=l2, tol=0.0001;, score=0.882 total time=  45.4s
# [CV 2/5; 19/48] START C=0.1, max_iter=200, penalty=l2, tol=0.0001...............
# [CV 2/5; 19/48] END C=0.1, max_iter=200, penalty=l2, tol=0.0001;, score=0.880 total time=  46.7s
# [CV 3/5; 19/48] START C=0.1, max_iter=200, penalty=l2, tol=0.0001...............
# [CV 3/5; 19/48] END C=0.1, max_iter=200, penalty=l2, tol=0.0001;, score=0.882 total time=  47.6s
# [CV 4/5; 19/48] START C=0.1, max_iter=200, penalty=l2, tol=0.0001...............
# [CV 4/5; 19/48] END C=0.1, max_iter=200, penalty=l2, tol=0.0001;, score=0.882 total time=  46.2s
# [CV 5/5; 19/48] START C=0.1, max_iter=200, penalty=l2, tol=0.0001...............
# [CV 5/5; 19/48] END C=0.1, max_iter=200, penalty=l2, tol=0.0001;, score=0.881 total time=  30.3s
# [CV 1/5; 20/48] START C=0.1, max_iter=200, penalty=l2, tol=0.001................
# [CV 1/5; 20/48] END C=0.1, max_iter=200, penalty=l2, tol=0.001;, score=0.846 total time=  19.7s
# [CV 2/5; 20/48] START C=0.1, max_iter=200, penalty=l2, tol=0.001................
# [CV 2/5; 20/48] END C=0.1, max_iter=200, penalty=l2, tol=0.001;, score=0.847 total time=  21.2s
# [CV 3/5; 20/48] START C=0.1, max_iter=200, penalty=l2, tol=0.001................
# [CV 3/5; 20/48] END C=0.1, max_iter=200, penalty=l2, tol=0.001;, score=0.850 total time=  22.2s
# [CV 4/5; 20/48] START C=0.1, max_iter=200, penalty=l2, tol=0.001................
# [CV 4/5; 20/48] END C=0.1, max_iter=200, penalty=l2, tol=0.001;, score=0.852 total time=  22.3s
# [CV 5/5; 20/48] START C=0.1, max_iter=200, penalty=l2, tol=0.001................
# [CV 5/5; 20/48] END C=0.1, max_iter=200, penalty=l2, tol=0.001;, score=0.846 total time=  20.2s
# [CV 1/5; 21/48] START C=0.1, max_iter=200, penalty=l2, tol=0.01.................
# [CV 1/5; 21/48] END C=0.1, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=   9.1s
# [CV 2/5; 21/48] START C=0.1, max_iter=200, penalty=l2, tol=0.01.................
# [CV 2/5; 21/48] END C=0.1, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=   9.4s
# [CV 3/5; 21/48] START C=0.1, max_iter=200, penalty=l2, tol=0.01.................
# [CV 3/5; 21/48] END C=0.1, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=   9.2s
# [CV 4/5; 21/48] START C=0.1, max_iter=200, penalty=l2, tol=0.01.................
# [CV 4/5; 21/48] END C=0.1, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=   8.8s
# [CV 5/5; 21/48] START C=0.1, max_iter=200, penalty=l2, tol=0.01.................
# [CV 5/5; 21/48] END C=0.1, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=   9.5s
# [CV 1/5; 22/48] START C=0.1, max_iter=200, penalty=l1, tol=0.0001...............
# [CV 1/5; 22/48] END C=0.1, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   5.3s
# [CV 2/5; 22/48] START C=0.1, max_iter=200, penalty=l1, tol=0.0001...............
# [CV 2/5; 22/48] END C=0.1, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   4.2s
# [CV 3/5; 22/48] START C=0.1, max_iter=200, penalty=l1, tol=0.0001...............
# [CV 3/5; 22/48] END C=0.1, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   3.9s
# [CV 4/5; 22/48] START C=0.1, max_iter=200, penalty=l1, tol=0.0001...............
# [CV 4/5; 22/48] END C=0.1, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   4.5s
# [CV 5/5; 22/48] START C=0.1, max_iter=200, penalty=l1, tol=0.0001...............
# [CV 5/5; 22/48] END C=0.1, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   4.4s
# [CV 1/5; 23/48] START C=0.1, max_iter=200, penalty=l1, tol=0.001................
# [CV 1/5; 23/48] END C=0.1, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   4.6s
# [CV 2/5; 23/48] START C=0.1, max_iter=200, penalty=l1, tol=0.001................
# [CV 2/5; 23/48] END C=0.1, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   4.3s
# [CV 3/5; 23/48] START C=0.1, max_iter=200, penalty=l1, tol=0.001................
# [CV 3/5; 23/48] END C=0.1, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   3.9s
# [CV 4/5; 23/48] START C=0.1, max_iter=200, penalty=l1, tol=0.001................
# [CV 4/5; 23/48] END C=0.1, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   4.7s
# [CV 5/5; 23/48] START C=0.1, max_iter=200, penalty=l1, tol=0.001................
# [CV 5/5; 23/48] END C=0.1, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   4.4s
# [CV 1/5; 24/48] START C=0.1, max_iter=200, penalty=l1, tol=0.01.................
# [CV 1/5; 24/48] END C=0.1, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   4.3s
# [CV 2/5; 24/48] START C=0.1, max_iter=200, penalty=l1, tol=0.01.................
# [CV 2/5; 24/48] END C=0.1, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   3.8s
# [CV 3/5; 24/48] START C=0.1, max_iter=200, penalty=l1, tol=0.01.................
# [CV 3/5; 24/48] END C=0.1, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   3.7s
# [CV 4/5; 24/48] START C=0.1, max_iter=200, penalty=l1, tol=0.01.................
# [CV 4/5; 24/48] END C=0.1, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   4.3s
# [CV 5/5; 24/48] START C=0.1, max_iter=200, penalty=l1, tol=0.01.................
# [CV 5/5; 24/48] END C=0.1, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   4.3s
# [CV 1/5; 25/48] START C=1.0, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 1/5; 25/48] END C=1.0, max_iter=100, penalty=l2, tol=0.0001;, score=0.896 total time= 1.1min
# [CV 2/5; 25/48] START C=1.0, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 2/5; 25/48] END C=1.0, max_iter=100, penalty=l2, tol=0.0001;, score=0.894 total time=  50.2s
# [CV 3/5; 25/48] START C=1.0, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 3/5; 25/48] END C=1.0, max_iter=100, penalty=l2, tol=0.0001;, score=0.893 total time=  50.3s
# [CV 4/5; 25/48] START C=1.0, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 4/5; 25/48] END C=1.0, max_iter=100, penalty=l2, tol=0.0001;, score=0.896 total time= 1.0min
# [CV 5/5; 25/48] START C=1.0, max_iter=100, penalty=l2, tol=0.0001...............
# [CV 5/5; 25/48] END C=1.0, max_iter=100, penalty=l2, tol=0.0001;, score=0.895 total time=  50.4s
# [CV 1/5; 26/48] START C=1.0, max_iter=100, penalty=l2, tol=0.001................
# [CV 1/5; 26/48] END C=1.0, max_iter=100, penalty=l2, tol=0.001;, score=0.896 total time=  34.3s
# [CV 2/5; 26/48] START C=1.0, max_iter=100, penalty=l2, tol=0.001................
# [CV 2/5; 26/48] END C=1.0, max_iter=100, penalty=l2, tol=0.001;, score=0.854 total time=  24.5s
# [CV 3/5; 26/48] START C=1.0, max_iter=100, penalty=l2, tol=0.001................
# [CV 3/5; 26/48] END C=1.0, max_iter=100, penalty=l2, tol=0.001;, score=0.858 total time=  24.2s
# [CV 4/5; 26/48] START C=1.0, max_iter=100, penalty=l2, tol=0.001................
# [CV 4/5; 26/48] END C=1.0, max_iter=100, penalty=l2, tol=0.001;, score=0.860 total time=  24.5s
# [CV 5/5; 26/48] START C=1.0, max_iter=100, penalty=l2, tol=0.001................
# [CV 5/5; 26/48] END C=1.0, max_iter=100, penalty=l2, tol=0.001;, score=0.857 total time=  26.9s
# [CV 1/5; 27/48] START C=1.0, max_iter=100, penalty=l2, tol=0.01.................
# [CV 1/5; 27/48] END C=1.0, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=   9.1s
# [CV 2/5; 27/48] START C=1.0, max_iter=100, penalty=l2, tol=0.01.................
# [CV 2/5; 27/48] END C=1.0, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=   9.5s
# [CV 3/5; 27/48] START C=1.0, max_iter=100, penalty=l2, tol=0.01.................
# [CV 3/5; 27/48] END C=1.0, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=   9.5s
# [CV 4/5; 27/48] START C=1.0, max_iter=100, penalty=l2, tol=0.01.................
# [CV 4/5; 27/48] END C=1.0, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=   9.1s
# [CV 5/5; 27/48] START C=1.0, max_iter=100, penalty=l2, tol=0.01.................
# [CV 5/5; 27/48] END C=1.0, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=   9.4s
# [CV 1/5; 28/48] START C=1.0, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 1/5; 28/48] END C=1.0, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   4.7s
# [CV 2/5; 28/48] START C=1.0, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 2/5; 28/48] END C=1.0, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   3.8s
# [CV 3/5; 28/48] START C=1.0, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 3/5; 28/48] END C=1.0, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   3.8s
# [CV 4/5; 28/48] START C=1.0, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 4/5; 28/48] END C=1.0, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   4.5s
# [CV 5/5; 28/48] START C=1.0, max_iter=100, penalty=l1, tol=0.0001...............
# [CV 5/5; 28/48] END C=1.0, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   4.7s
# [CV 1/5; 29/48] START C=1.0, max_iter=100, penalty=l1, tol=0.001................
# [CV 1/5; 29/48] END C=1.0, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   4.4s
# [CV 2/5; 29/48] START C=1.0, max_iter=100, penalty=l1, tol=0.001................
# [CV 2/5; 29/48] END C=1.0, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   3.9s
# [CV 3/5; 29/48] START C=1.0, max_iter=100, penalty=l1, tol=0.001................
# [CV 3/5; 29/48] END C=1.0, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   3.8s
# [CV 4/5; 29/48] START C=1.0, max_iter=100, penalty=l1, tol=0.001................
# [CV 4/5; 29/48] END C=1.0, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   4.5s
# [CV 5/5; 29/48] START C=1.0, max_iter=100, penalty=l1, tol=0.001................
# [CV 5/5; 29/48] END C=1.0, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   4.6s
# [CV 1/5; 30/48] START C=1.0, max_iter=100, penalty=l1, tol=0.01.................
# [CV 1/5; 30/48] END C=1.0, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   4.6s
# [CV 2/5; 30/48] START C=1.0, max_iter=100, penalty=l1, tol=0.01.................
# [CV 2/5; 30/48] END C=1.0, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   4.2s
# [CV 3/5; 30/48] START C=1.0, max_iter=100, penalty=l1, tol=0.01.................
# [CV 3/5; 30/48] END C=1.0, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   4.6s
# [CV 4/5; 30/48] START C=1.0, max_iter=100, penalty=l1, tol=0.01.................
# [CV 4/5; 30/48] END C=1.0, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   5.2s
# [CV 5/5; 30/48] START C=1.0, max_iter=100, penalty=l1, tol=0.01.................
# [CV 5/5; 30/48] END C=1.0, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   4.9s
# [CV 1/5; 31/48] START C=1.0, max_iter=200, penalty=l2, tol=0.0001...............
# [CV 1/5; 31/48] END C=1.0, max_iter=200, penalty=l2, tol=0.0001;, score=0.896 total time= 1.1min
# [CV 2/5; 31/48] START C=1.0, max_iter=200, penalty=l2, tol=0.0001...............
# [CV 2/5; 31/48] END C=1.0, max_iter=200, penalty=l2, tol=0.0001;, score=0.894 total time=  50.7s
# [CV 3/5; 31/48] START C=1.0, max_iter=200, penalty=l2, tol=0.0001...............
# [CV 3/5; 31/48] END C=1.0, max_iter=200, penalty=l2, tol=0.0001;, score=0.893 total time=  50.7s
# [CV 4/5; 31/48] START C=1.0, max_iter=200, penalty=l2, tol=0.0001...............
# [CV 4/5; 31/48] END C=1.0, max_iter=200, penalty=l2, tol=0.0001;, score=0.896 total time= 1.0min
# [CV 5/5; 31/48] START C=1.0, max_iter=200, penalty=l2, tol=0.0001...............
# [CV 5/5; 31/48] END C=1.0, max_iter=200, penalty=l2, tol=0.0001;, score=0.895 total time=  51.0s
# [CV 1/5; 32/48] START C=1.0, max_iter=200, penalty=l2, tol=0.001................
# [CV 1/5; 32/48] END C=1.0, max_iter=200, penalty=l2, tol=0.001;, score=0.896 total time=  36.5s
# [CV 2/5; 32/48] START C=1.0, max_iter=200, penalty=l2, tol=0.001................
# [CV 2/5; 32/48] END C=1.0, max_iter=200, penalty=l2, tol=0.001;, score=0.854 total time=  24.7s
# [CV 3/5; 32/48] START C=1.0, max_iter=200, penalty=l2, tol=0.001................
# [CV 3/5; 32/48] END C=1.0, max_iter=200, penalty=l2, tol=0.001;, score=0.858 total time=  24.4s
# [CV 4/5; 32/48] START C=1.0, max_iter=200, penalty=l2, tol=0.001................
# [CV 4/5; 32/48] END C=1.0, max_iter=200, penalty=l2, tol=0.001;, score=0.860 total time=  24.2s
# [CV 5/5; 32/48] START C=1.0, max_iter=200, penalty=l2, tol=0.001................
# [CV 5/5; 32/48] END C=1.0, max_iter=200, penalty=l2, tol=0.001;, score=0.857 total time=  24.9s
# [CV 1/5; 33/48] START C=1.0, max_iter=200, penalty=l2, tol=0.01.................
# [CV 1/5; 33/48] END C=1.0, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=   9.4s
# [CV 2/5; 33/48] START C=1.0, max_iter=200, penalty=l2, tol=0.01.................
# [CV 2/5; 33/48] END C=1.0, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=   9.6s
# [CV 3/5; 33/48] START C=1.0, max_iter=200, penalty=l2, tol=0.01.................
# [CV 3/5; 33/48] END C=1.0, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=   9.1s
# [CV 4/5; 33/48] START C=1.0, max_iter=200, penalty=l2, tol=0.01.................
# [CV 4/5; 33/48] END C=1.0, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=   9.7s
# [CV 5/5; 33/48] START C=1.0, max_iter=200, penalty=l2, tol=0.01.................
# [CV 5/5; 33/48] END C=1.0, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=   9.4s
# [CV 1/5; 34/48] START C=1.0, max_iter=200, penalty=l1, tol=0.0001...............
# [CV 1/5; 34/48] END C=1.0, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   4.5s
# [CV 2/5; 34/48] START C=1.0, max_iter=200, penalty=l1, tol=0.0001...............
# [CV 2/5; 34/48] END C=1.0, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   4.0s
# [CV 3/5; 34/48] START C=1.0, max_iter=200, penalty=l1, tol=0.0001...............
# [CV 3/5; 34/48] END C=1.0, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   4.5s
# [CV 4/5; 34/48] START C=1.0, max_iter=200, penalty=l1, tol=0.0001...............
# [CV 4/5; 34/48] END C=1.0, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   4.5s
# [CV 5/5; 34/48] START C=1.0, max_iter=200, penalty=l1, tol=0.0001...............
# [CV 5/5; 34/48] END C=1.0, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   5.0s
# [CV 1/5; 35/48] START C=1.0, max_iter=200, penalty=l1, tol=0.001................
# [CV 1/5; 35/48] END C=1.0, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   4.3s
# [CV 2/5; 35/48] START C=1.0, max_iter=200, penalty=l1, tol=0.001................
# [CV 2/5; 35/48] END C=1.0, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   4.3s
# [CV 3/5; 35/48] START C=1.0, max_iter=200, penalty=l1, tol=0.001................
# [CV 3/5; 35/48] END C=1.0, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   3.9s
# [CV 4/5; 35/48] START C=1.0, max_iter=200, penalty=l1, tol=0.001................
# [CV 4/5; 35/48] END C=1.0, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   4.6s
# [CV 5/5; 35/48] START C=1.0, max_iter=200, penalty=l1, tol=0.001................
# [CV 5/5; 35/48] END C=1.0, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   4.8s
# [CV 1/5; 36/48] START C=1.0, max_iter=200, penalty=l1, tol=0.01.................
# [CV 1/5; 36/48] END C=1.0, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   5.0s
# [CV 2/5; 36/48] START C=1.0, max_iter=200, penalty=l1, tol=0.01.................
# [CV 2/5; 36/48] END C=1.0, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   4.1s
# [CV 3/5; 36/48] START C=1.0, max_iter=200, penalty=l1, tol=0.01.................
# [CV 3/5; 36/48] END C=1.0, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   4.0s
# [CV 4/5; 36/48] START C=1.0, max_iter=200, penalty=l1, tol=0.01.................
# [CV 4/5; 36/48] END C=1.0, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   4.9s
# [CV 5/5; 36/48] START C=1.0, max_iter=200, penalty=l1, tol=0.01.................
# [CV 5/5; 36/48] END C=1.0, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   4.4s
# [CV 1/5; 37/48] START C=10, max_iter=100, penalty=l2, tol=0.0001................
# [CV 1/5; 37/48] END C=10, max_iter=100, penalty=l2, tol=0.0001;, score=0.893 total time=  57.4s
# [CV 2/5; 37/48] START C=10, max_iter=100, penalty=l2, tol=0.0001................
# [CV 2/5; 37/48] END C=10, max_iter=100, penalty=l2, tol=0.0001;, score=0.890 total time= 1.1min
# [CV 3/5; 37/48] START C=10, max_iter=100, penalty=l2, tol=0.0001................
# [CV 3/5; 37/48] END C=10, max_iter=100, penalty=l2, tol=0.0001;, score=0.888 total time=  59.9s
# [CV 4/5; 37/48] START C=10, max_iter=100, penalty=l2, tol=0.0001................
# [CV 4/5; 37/48] END C=10, max_iter=100, penalty=l2, tol=0.0001;, score=0.893 total time= 1.0min
# [CV 5/5; 37/48] START C=10, max_iter=100, penalty=l2, tol=0.0001................
# [CV 5/5; 37/48] END C=10, max_iter=100, penalty=l2, tol=0.0001;, score=0.889 total time= 1.7min
# [CV 1/5; 38/48] START C=10, max_iter=100, penalty=l2, tol=0.001.................
# [CV 1/5; 38/48] END C=10, max_iter=100, penalty=l2, tol=0.001;, score=0.887 total time=  36.3s
# [CV 2/5; 38/48] START C=10, max_iter=100, penalty=l2, tol=0.001.................
# [CV 2/5; 38/48] END C=10, max_iter=100, penalty=l2, tol=0.001;, score=0.853 total time=  27.8s
# [CV 3/5; 38/48] START C=10, max_iter=100, penalty=l2, tol=0.001.................
# [CV 3/5; 38/48] END C=10, max_iter=100, penalty=l2, tol=0.001;, score=0.857 total time=  27.7s
# [CV 4/5; 38/48] START C=10, max_iter=100, penalty=l2, tol=0.001.................
# [CV 4/5; 38/48] END C=10, max_iter=100, penalty=l2, tol=0.001;, score=0.859 total time=  25.1s
# [CV 5/5; 38/48] START C=10, max_iter=100, penalty=l2, tol=0.001.................
# [CV 5/5; 38/48] END C=10, max_iter=100, penalty=l2, tol=0.001;, score=0.856 total time=  24.8s
# [CV 1/5; 39/48] START C=10, max_iter=100, penalty=l2, tol=0.01..................
# [CV 1/5; 39/48] END C=10, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=   9.3s
# [CV 2/5; 39/48] START C=10, max_iter=100, penalty=l2, tol=0.01..................
# [CV 2/5; 39/48] END C=10, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=  10.2s
# [CV 3/5; 39/48] START C=10, max_iter=100, penalty=l2, tol=0.01..................
# [CV 3/5; 39/48] END C=10, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=   9.7s
# [CV 4/5; 39/48] START C=10, max_iter=100, penalty=l2, tol=0.01..................
# [CV 4/5; 39/48] END C=10, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=   9.4s
# [CV 5/5; 39/48] START C=10, max_iter=100, penalty=l2, tol=0.01..................
# [CV 5/5; 39/48] END C=10, max_iter=100, penalty=l2, tol=0.01;, score=0.500 total time=  10.7s
# [CV 1/5; 40/48] START C=10, max_iter=100, penalty=l1, tol=0.0001................
# [CV 1/5; 40/48] END C=10, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   4.5s
# [CV 2/5; 40/48] START C=10, max_iter=100, penalty=l1, tol=0.0001................
# [CV 2/5; 40/48] END C=10, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   4.5s
# [CV 3/5; 40/48] START C=10, max_iter=100, penalty=l1, tol=0.0001................
# [CV 3/5; 40/48] END C=10, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   5.2s
# [CV 4/5; 40/48] START C=10, max_iter=100, penalty=l1, tol=0.0001................
# [CV 4/5; 40/48] END C=10, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   5.6s
# [CV 5/5; 40/48] START C=10, max_iter=100, penalty=l1, tol=0.0001................
# [CV 5/5; 40/48] END C=10, max_iter=100, penalty=l1, tol=0.0001;, score=nan total time=   6.0s
# [CV 1/5; 41/48] START C=10, max_iter=100, penalty=l1, tol=0.001.................
# [CV 1/5; 41/48] END C=10, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   5.5s
# [CV 2/5; 41/48] START C=10, max_iter=100, penalty=l1, tol=0.001.................
# [CV 2/5; 41/48] END C=10, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   4.4s
# [CV 3/5; 41/48] START C=10, max_iter=100, penalty=l1, tol=0.001.................
# [CV 3/5; 41/48] END C=10, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   4.6s
# [CV 4/5; 41/48] START C=10, max_iter=100, penalty=l1, tol=0.001.................
# [CV 4/5; 41/48] END C=10, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   4.3s
# [CV 5/5; 41/48] START C=10, max_iter=100, penalty=l1, tol=0.001.................
# [CV 5/5; 41/48] END C=10, max_iter=100, penalty=l1, tol=0.001;, score=nan total time=   5.2s
# [CV 1/5; 42/48] START C=10, max_iter=100, penalty=l1, tol=0.01..................
# [CV 1/5; 42/48] END C=10, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   5.0s
# [CV 2/5; 42/48] START C=10, max_iter=100, penalty=l1, tol=0.01..................
# [CV 2/5; 42/48] END C=10, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   4.7s
# [CV 3/5; 42/48] START C=10, max_iter=100, penalty=l1, tol=0.01..................
# [CV 3/5; 42/48] END C=10, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   4.9s
# [CV 4/5; 42/48] START C=10, max_iter=100, penalty=l1, tol=0.01..................
# [CV 4/5; 42/48] END C=10, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   4.7s
# [CV 5/5; 42/48] START C=10, max_iter=100, penalty=l1, tol=0.01..................
# [CV 5/5; 42/48] END C=10, max_iter=100, penalty=l1, tol=0.01;, score=nan total time=   5.9s
# [CV 1/5; 43/48] START C=10, max_iter=200, penalty=l2, tol=0.0001................
# [CV 1/5; 43/48] END C=10, max_iter=200, penalty=l2, tol=0.0001;, score=0.893 total time= 1.1min
# [CV 2/5; 43/48] START C=10, max_iter=200, penalty=l2, tol=0.0001................
# [CV 2/5; 43/48] END C=10, max_iter=200, penalty=l2, tol=0.0001;, score=0.890 total time= 1.2min
# [CV 3/5; 43/48] START C=10, max_iter=200, penalty=l2, tol=0.0001................
# [CV 3/5; 43/48] END C=10, max_iter=200, penalty=l2, tol=0.0001;, score=0.888 total time= 1.0min
# [CV 4/5; 43/48] START C=10, max_iter=200, penalty=l2, tol=0.0001................
# [CV 4/5; 43/48] END C=10, max_iter=200, penalty=l2, tol=0.0001;, score=0.893 total time= 1.0min
# [CV 5/5; 43/48] START C=10, max_iter=200, penalty=l2, tol=0.0001................
# [CV 5/5; 43/48] END C=10, max_iter=200, penalty=l2, tol=0.0001;, score=0.889 total time= 1.6min
# [CV 1/5; 44/48] START C=10, max_iter=200, penalty=l2, tol=0.001.................
# [CV 1/5; 44/48] END C=10, max_iter=200, penalty=l2, tol=0.001;, score=0.887 total time=  30.8s
# [CV 2/5; 44/48] START C=10, max_iter=200, penalty=l2, tol=0.001.................
# [CV 2/5; 44/48] END C=10, max_iter=200, penalty=l2, tol=0.001;, score=0.853 total time=  28.8s
# [CV 3/5; 44/48] START C=10, max_iter=200, penalty=l2, tol=0.001.................
# [CV 3/5; 44/48] END C=10, max_iter=200, penalty=l2, tol=0.001;, score=0.857 total time=  23.8s
# [CV 4/5; 44/48] START C=10, max_iter=200, penalty=l2, tol=0.001.................
# [CV 4/5; 44/48] END C=10, max_iter=200, penalty=l2, tol=0.001;, score=0.859 total time=  25.3s
# [CV 5/5; 44/48] START C=10, max_iter=200, penalty=l2, tol=0.001.................
# [CV 5/5; 44/48] END C=10, max_iter=200, penalty=l2, tol=0.001;, score=0.856 total time=  25.7s
# [CV 1/5; 45/48] START C=10, max_iter=200, penalty=l2, tol=0.01..................
# [CV 1/5; 45/48] END C=10, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=   9.8s
# [CV 2/5; 45/48] START C=10, max_iter=200, penalty=l2, tol=0.01..................
# [CV 2/5; 45/48] END C=10, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=  10.1s
# [CV 3/5; 45/48] START C=10, max_iter=200, penalty=l2, tol=0.01..................
# [CV 3/5; 45/48] END C=10, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=   9.6s
# [CV 4/5; 45/48] START C=10, max_iter=200, penalty=l2, tol=0.01..................
# [CV 4/5; 45/48] END C=10, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=   9.5s
# [CV 5/5; 45/48] START C=10, max_iter=200, penalty=l2, tol=0.01..................
# [CV 5/5; 45/48] END C=10, max_iter=200, penalty=l2, tol=0.01;, score=0.500 total time=   9.3s
# [CV 1/5; 46/48] START C=10, max_iter=200, penalty=l1, tol=0.0001................
# [CV 1/5; 46/48] END C=10, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   4.2s
# [CV 2/5; 46/48] START C=10, max_iter=200, penalty=l1, tol=0.0001................
# [CV 2/5; 46/48] END C=10, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   4.0s
# [CV 3/5; 46/48] START C=10, max_iter=200, penalty=l1, tol=0.0001................
# [CV 3/5; 46/48] END C=10, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   3.8s
# [CV 4/5; 46/48] START C=10, max_iter=200, penalty=l1, tol=0.0001................
# [CV 4/5; 46/48] END C=10, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   4.6s
# [CV 5/5; 46/48] START C=10, max_iter=200, penalty=l1, tol=0.0001................
# [CV 5/5; 46/48] END C=10, max_iter=200, penalty=l1, tol=0.0001;, score=nan total time=   4.5s
# [CV 1/5; 47/48] START C=10, max_iter=200, penalty=l1, tol=0.001.................
# [CV 1/5; 47/48] END C=10, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   4.3s
# [CV 2/5; 47/48] START C=10, max_iter=200, penalty=l1, tol=0.001.................
# [CV 2/5; 47/48] END C=10, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   4.2s
# [CV 3/5; 47/48] START C=10, max_iter=200, penalty=l1, tol=0.001.................
# [CV 3/5; 47/48] END C=10, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   3.9s
# [CV 4/5; 47/48] START C=10, max_iter=200, penalty=l1, tol=0.001.................
# [CV 4/5; 47/48] END C=10, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   4.5s
# [CV 5/5; 47/48] START C=10, max_iter=200, penalty=l1, tol=0.001.................
# [CV 5/5; 47/48] END C=10, max_iter=200, penalty=l1, tol=0.001;, score=nan total time=   4.7s
# [CV 1/5; 48/48] START C=10, max_iter=200, penalty=l1, tol=0.01..................
# [CV 1/5; 48/48] END C=10, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   4.9s
# [CV 2/5; 48/48] START C=10, max_iter=200, penalty=l1, tol=0.01..................
# [CV 2/5; 48/48] END C=10, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   4.3s
# [CV 3/5; 48/48] START C=10, max_iter=200, penalty=l1, tol=0.01..................
# [CV 3/5; 48/48] END C=10, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   4.1s
# [CV 4/5; 48/48] START C=10, max_iter=200, penalty=l1, tol=0.01..................
# [CV 4/5; 48/48] END C=10, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   4.9s
# [CV 5/5; 48/48] START C=10, max_iter=200, penalty=l1, tol=0.01..................
# [CV 5/5; 48/48] END C=10, max_iter=200, penalty=l1, tol=0.01;, score=nan total time=   5.0s
# Best Score: 0.8950208333333333
# Best hyperparameter set:
# 	C: 1.0
# 	max_iter: 100
# 	penalty: l2
# 	tol: 0.0001

# %%
f1_score_5 = f1_score(y_test, model_5.predict(X_test_tfidf), average = 'weighted')

print("Training dataset:")
print("Precision Score", precision_score(y_train, model_5.predict(X_train_tfidf), average = 'micro'))
print("f1 Score", f1_score(y_train, model_5.predict(X_train_tfidf), average = 'weighted'))
print(" ")

print("Test dataset:")
print("Precision Score", precision_score(y_test, model_5.predict(X_test_tfidf), average = 'micro'))
print("f1 Score", f1_score(y_test, model_5.predict(X_test_tfidf), average = 'weighted'))
print(" ")
# Out:
# Training dataset:
# Precision Score 0.9132291666666666
# f1 Score 0.9132286857713058
#
# Test dataset:
# Precision Score 0.6057083333333333
# f1 Score 0.6048585260267842

# %% [markdown]
# Settling down with the logistic regression for better training speed and accuracy
